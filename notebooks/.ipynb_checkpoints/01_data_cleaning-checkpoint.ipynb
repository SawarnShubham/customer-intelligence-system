# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_excel("../data/raw/Online Retail.xlsx")

# Preview
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2 import numpy as np
#       3
#       4 # Load dataset
# ----> 5 df = pd.read_excel("../data/raw/Online Retail.xlsx")
#       6
#       7 # Preview
#       8 df.head()
#
# File c:\Users\digit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:494, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#     493 try:
# ...
